# %%
from urllib.request import urlopen
import json
from datetime import datetime
import matplotlib.pyplot as plt
from collections import defaultdict
import pandas as pd
# %matplotlib inline

# %%
def get_recent_article(result=[],article_id=None,sort_key=None,date_span=7):
    # api url
    if not(article_id) and not(sort_key):
        article_api   = "https://alis.to/api/articles/recent?limit=100"
    else:
        article_api   = "https://alis.to/api/articles/recent?limit=100&article_id=%s&sort_key=%s" % (article_id,sort_key)
    # データ取得
    raw_article_data  = urlopen(article_api).read().decode("utf-8") 
    json_article_data = json.loads(raw_article_data)                    
    articles_data     = json_article_data["Items"]
    result.extend(articles_data)
    # ループ終了のチェック
    today             = datetime.now() 
    last_data_date    = datetime.fromtimestamp(int(result[-1]["published_at"]))
    if (today-last_data_date).days >= (date_span+1):
        # ループ終了
        return result
    else:
        # ループ継続
        # 次のデータ取得用パラメータ
        LastEvaluatedKey  = json_article_data["LastEvaluatedKey"]
        article_id        = LastEvaluatedKey["article_id"]
        sort_key          = LastEvaluatedKey["sort_key"]
        return get_recent_article(result,article_id,sort_key)

# %%
def get_recent_article(result=[],article_id=None,sort_key=None,date_span=7):
    # api url
    if not(article_id) and not(sort_key):
        article_api   = "https://alis.to/api/articles/recent?limit=100"
    else:
        article_api   = "https://alis.to/api/articles/recent?limit=100&article_id=%s&sort_key=%s" % (article_id,sort_key)
    # データ取得
    raw_article_data  = urlopen(article_api).read().decode("utf-8") 
    json_article_data = json.loads(raw_article_data)                    
    articles_data     = json_article_data["Items"]
    result.extend(articles_data)
    # ループ終了のチェック
    today             = datetime.now() 
    last_data_date    = datetime.fromtimestamp(int(result[-1]["published_at"]))
    if (today-last_data_date).days >= (date_span+1):
        # ループ終了
        return result
    else:
        # ループ継続
        # 次のデータ取得用パラメータ
        LastEvaluatedKey  = json_article_data["LastEvaluatedKey"]
        article_id        = LastEvaluatedKey["article_id"]
        sort_key          = LastEvaluatedKey["sort_key"]
        return get_recent_article(result,article_id,sort_key)

# %%
def get_like_count(article_id):
    likes_api      = "https://alis.to/api/articles/%s/likes"
    raw_like_data  = urlopen(likes_api % article_id).read().decode("utf-8") 
    json_like_data = json.loads(raw_like_data)                              
    like_count     = json_like_data["count"]
    return like_count

# %%
def get_user_name(user_id):
    user_api      = "https://alis.to/api/users/%s/info"
    raw_user_data = urlopen(user_api % user_id).read().decode("utf-8")     
    user_data     = json.loads(raw_user_data) 
    name          = user_data["user_display_name"]
    return name

# %%
def make_data(articles):
    data = []
    for article in articles:
        title      = article["title"]
        user_id    = article["user_id"]
        article_id = article["article_id"]
        user_name  = get_user_name(user_id)
        like_count = get_like_count(article_id)
        date       = datetime.fromtimestamp(int(article["published_at"]))
        url        = "https://alis.to/%s/articles/%s" % (user_id,article_id)
        data.append([title,url,user_name,like_count,date])
    return data

# %%
def make_rankig(data):
    ranking = pd.DataFrame(data,columns=["titel","url","autehr","like","date"])
    not_old = ranking["date"].map(lambda x:x.day) != ranking["date"].min().day
    not_new = ranking["date"].map(lambda x:x.day) != ranking["date"].max().day
    ranking = ranking[not_old & not_new]
    ranking = ranking.sort_values("like",ascending=False)
    return ranking

# %%
articles = get_recent_article()
data     = make_data(articles)
ranking  = make_rankig(data)
ranking
# Out:
#                                                titel  \
# 628                          【宣言】僕はALISで億り人になります【戦略】
# 201                        【必見】Alisista図鑑を作ってみた【初心者】
# 331                                        ALISがおかしい
# 490                           そこのキミ！ALISのコミュニティへカモン！
# 240                                ALISエンジョイ勢のみなさまへ。
# 160                                    もしも私が億り人になったら
# 530                       ALISAA -デニムの夏がやってくる 毛根女子編-
# 263                                 漫画焼かれ続ける男　1話、2話
# 132                             日本の取引所に上場させたいお前らに物申す
# 407                毛根女子のalisistaと対談シリーズvol.12 yumeさん
# 590                                     毛根侍13話　あばよ相棒
# 154                             継続は力なりだし持つべきものは友だしの話
# 450                      今ALISで記事を書くのは？...。バ、バイトする？ｗ
# 338                           ［入門編］ÐAppsってどんなもの？《前篇》
# 461                                          毛根侍　番外編
# 740            内輪で盛り上がることの効果ーヴォエからみるグロース戦略への多角的アプローチ
# 360                                毛根侍第2部1話ビットコインチュウ
# 688                                    毛根侍12話　ビットコイン
# 393                         ALISAA-ALISから広がる宇宙-毛根女子編
# 620                    仮想通貨でのコミュニティの大切さを広瀬隆雄さんの発言に見る
# 692                                アリスマン流！いいね♡の基準３選！
# 86               毛根女子のalisistaと対談シリーズvol.15 ブルーモアイさん
# 658                 毛根女子のalisistaと対談シリーズvol.10れんとくさん
# 306               毛根女子のalisistaと対談シリーズvol.13HIDETOさん
# 319                                  ALIS APIを公開しました
# 402                   ALISAAやってみた！「Happy ALIS LIFE」！
# 509                       【ALISAA】和柄のALISうさぎ＊ミカヅキカヅキ
# 237            【仮想通貨鎖国？！】Huobi、日本に居住するお客さま向けのサービスを停止
# 597                          「いいね」の伸びやすい記事には共通点がある！？
# 473                  毛根女子のalisistaと対談シリーズvol.11ゆうきさん
# ..                                               ...
# 506                             ALISラジオ(非公式)アーカイブまとめ
# 29                                 ＬＩＮＥ、７月に仮想通貨交換所開始
# 6                       仮想通貨の総合ランキングサイト[bitgur]をご紹介！
# 12                                日本居住者向けのサービス停止について
# 727                    ★食事の速度や永久歯の数、歯周病の重症度が肥満に影響する！
# 545                                コメント機能実装 コメント出来ない
# 99                          ポインセチアを美しく育てよう！育て方の５つのコツ
# 23                          Peepcoinの買い注文が0BTCのようです。
# 714                                             切替えて
# 217                           すぐにフォークするブロックチェーンは正なのか
# 580                       記事ないURLがリンクになっていないのに気づく遅さ…
# 28                        ビッサム、盗まれた仮想通貨１４００万ドル分回収と断言
# 584                       💫いま大注目の取引所トークン⑦ - Prandex💫
# 354                         【昭和のマイナー曲紹介】小山ルミ「わたしの祈り」
# 46                                  仮想通貨でまだ消耗し…うぐっ！！
# 752  【昭和のマイナー曲紹介】魔法の天使クリィミーマミの挿入歌「BIN♡KANルージュ」（太田貴子）
# 535                                         知事選と額紫陽花
# 32                         OGP展開テスト（テスト用なので無視してください）
# 67                           #NEM　二番底決まったので買っていいのでは？
# 14                          【素材集】シンプルな「色付きの棒線」を作ってみた
# 401                            ４人のＢＣ起業家、ティール・アワードを獲得
# 61                                 ウーパールーパーのつぶやき  53
# 10                                        仮想通貨取引所の物語
# 7                             ALISに480万投資　「＋3万」　20日目
# 9                                   ブロックチェーン学習日記57日目
# 65                                       やっぱり割れそう。。。
# 17                                       ALISで過ごす夏競馬
# 45                     LINEが仮想通貨交換事業に参入キタ━━(ﾟ∀ﾟ)━━！！
# 66                                 昨日引いた線でピッタリ止まってるｗ
# 31                           ひじきサラダをメニューにする時の５つのポイント
#
#                                                    url           autehr  like  \
# 628      https://alis.to/alisman/articles/3NjE4Aldw86O          alisman   118
# 201      https://alis.to/alisman/articles/2xANXLBREn58          alisman    83
# 331      https://alis.to/ionbtic/articles/2xAN4804BoNP    いおんぶてぃっく＠クソコラ    81
